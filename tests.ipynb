# %%
import pandas as pd

main = pd.read_csv('/Users/dmk6603/Documents/sbom_business_list/12_web_app/production_git/sbom_web_app/data/MAIN_global2000_complete.csv')
# global_company,github_profile,github_profile_name,followers,following,public_repos,site_url,avatar_url,location,email,is_verified,type,total_repos,total_projects,total_stars,total_forks,total_open_issues,primary_languages,name,sic,profit,market_value,sales,rank,country,assets,total_vulnerable_libraries_per_repo,total_libraries_per_repo,total_unique_libraries_per_repo,total_unique_versions_per_repo,avg_percentage_vulnerable_libraries_per_repo,avg_percentage_unique_versions_per_repo,vulnerable_repositories_count,non_vulnerable_repositories_count,percentage_vulnerable_repositories,repositories_with_zero_libraries,repositories_with_non_zero_libraries,average_unique_vulnerabilities,medium_libraries_count,medium_unique_libraries_count,active_repos_count,inactive_repos_count,vulnerable_repos_count,vulnerable_repos_percentage,percentage_repositories_with_vulnerabilities,repositories_with_vulnerabilities,total_repositories_analyzed,total_active_repositories,active_repositories_with_vulnerabilities,percentage_active_repositories_with_vulnerabilities,total_non_active_repositories,non_active_repositories_with_vulnerabilities,percentage_non_active_repositories_with_vulnerabilities,organization,is_tech_company
# JPMorgan Chase,https://github.com/jpmorganchase,jpmorganchase,2483.0,0.0,74.0,https://www.jpmorganchase.com,https://avatars.githubusercontent.com/u/22640571?v=4,,open_source@jpmorgan.com,False,Organization,74.0,0.0,12667.0,2559.0,803.0,"C++, Go, HTML, Java, JavaScript, Jupyter Notebook, Python, R, TypeScript",JPMorgan Chase,Banking,$42.12 B,$374.45 B,$124.54 B,4,United States,"$3,954.69 B",758.0,24068.0,20256.0,9160.0,8.690935134313666,75.99915849064031,40.0,16.0,54.054054054054056,17.0,57.0,361.7142857142857,26.5,26.0,4.0,70.0,40.0,54.054054054054056,0.0,0.0,74.0,4.0,3.0,75.0,53.0,54.0,101.88679245283019,jpmorganchase,False
# Amazon,https://github.com/amzn,amzn,2143.0,0.0,161.0,https://developer.amazon.com/,https://avatars.githubusercontent.com/u/8594673?v=4,,,False,Organization,161.0,0.0,14806.0,6153.0,864.0,"C, C#, C++, CSS, Go, HTML, Java, JavaScript, Jupyter Notebook, Kotlin, Mustache, Objective-C, PHP, PowerShell, Python, Ruby, Scala, Smarty, Swift, TypeScript, Zeek",Amazon,Retail and Wholesale,$33.36 B,"$1,468.4 B",$469.82 B,6,United States,$420.55 B,250.0,3748.0,3315.0,2525.0,9.699969267186443,89.47400943078799,40.0,50.0,24.84472049689441,71.0,90.0,36.833333333333336,9.5,9.5,11.0,150.0,40.0,24.84472049689441,0.0,0.0,161.0,11.0,6.0,54.54545454545454,84.0,85.0,101.19047619047619,amzn,False
# Apple,https://github.com/apple,apple,31348.0,0.0,333.0,https://apple.com,https://avatars.githubusercontent.com/u/10639145?v=4,"Cupertino, CA",,True,Organization,333.0,0.0,243261.0,21530.0,5419.0,"Assembly, C, C#, C++, Go, Groovy, HTML, Java, JavaScript, Jupyter Notebook, Kotlin, LLVM, Lua, Mathematica, Pkl, Python, R, Ruby, Shell, Starlark, Svelte, Swift, TypeScript",Apple,Technology Hardware & Equipment,$100.56 B,"$2,640.32 B",$378.7 B,7,United States,$381.19 B,360.0,7798.0,7153.0,4122.0,11.452012369323619,77.30810483407221,71.0,93.0,21.32132132132132,167.0,166.0,43.61585365853659,7.0,7.0,74.0,259.0,71.0,21.32132132132132,0.0,0.0,333.0,74.0,52.0,70.27027027027027,114.0,115.0,100.87719298245614,apple,True

profiles = pd.read_csv('/Users/dmk6603/Documents/forbes_global_2000/5_summaries/output/summaries/profiles_summary_complete.csv')
#organization,followers,following,public_repos,site_url,location,email,is_verified,type,total_repos,total_projects,total_stars,total_forks,total_open_issues,primary_languages
#synopsys-sig,65,0,27,https://www.synopsys.com/,,,False,Organization,27,0,190,115,147,"Go, HTML, Java, JavaScript, PowerShell, Python, Ruby, Shell, Smarty, TypeScript"

repositories = pd.read_csv('/Users/dmk6603/Documents/sbom_business_list/12_web_app/production_git/sbom_web_app/data/repositories_summary_with_zero_libs.csv')
# organization,repository_name,full_name,description,stars,forks,watchers,open_issues,primary_language,size_gb,created_at,updated_at,repository_url,days_since_last_update,is_active,repository,vulnerable_libraries_count,total_libraries,total_unique_libraries,total_unique_versions,percentage_vulnerable_libraries,percentage_unique_versions,vulnerable_repo,zero_libraries
# synopsys-sig,tslint-angular-security,synopsys-sig/tslint-angular-security,  TSLint rules for Angular,18,4,18,0,typescript,0.0,2018-11-26T17:01:47Z,2024-08-12 19:43:35+00:00,https://github.com/synopsys-sig/tslint-angular-security,370,no,tslint-angular-security,5.0,37.0,37.0,33.0,13.513513513513514,89.1891891891892,yes,False
# synopsys-sig,detect-scripts,synopsys-sig/detect-scripts,,2,5,2,3,powershell,0.0006,2019-02-26T17:44:10Z,2025-08-06 17:14:13+00:00,https://github.com/synopsys-sig/detect-scripts,11,no,detect-scripts,0.0,1.0,1.0,1.0,0.0,100.0,no,False


libs_with_details = pd.read_csv('/Users/dmk6603/Documents/sbom_business_list/12_web_app/production_git/sbom_web_app/data/libraries_with_detailed_vulnerability_status.csv')
# organization,repository,library,version,type,path,is_vulnerable,vulnerability_count,severities
# nordstrom,chef_vault_testfixtures_cookbook,addressable,2.3.8,gem,/Gemfile.lock,True,27,High
# nordstrom,chef_vault_testfixtures_cookbook,ast,2.0.0,gem,/Gemfile.lock,False,0,
# nordstrom,chef_vault_testfixtures_cookbook,astrolabe,1.3.0,gem,/Gemfile.lock,False,0,
# nordstrom,chef_vault_testfixtures_cookbook,berkshelf,3.2.3,gem,/Gemfile.lock,False,0,

vulnerabilities = pd.read_csv('/Users/dmk6603/Documents/sbom_business_list/12_web_app/production_git/sbom_web_app/data/vulnerability_summary.csv')
# Organization,repository,vulnerability_id,package_name,installed_version,severity,fixed_version,description,links
# adobe,external-dns,GHSA-mh63-6h87-95cp,github.com/golang-jwt/jwt/v4,v4.5.0,High,N/A,jwt-go allows excessive memory allocation during header parsing,https://github.com/advisories/GHSA-mh63-6h87-95cp


# total unique organizations for main
print(f"Total unique organizations in main: {main['organization'].nunique()}")

# total unique organizations for profiles
print(f"Total unique organizations in profiles: {profiles['organization'].nunique()}")

# total unique organizations for repos
print(f"Total unique organizations in repos: {repositories['organization'].nunique()}")

# total unique organizations for libraries
print(f"Total unique organizations in libraries: {libs_with_details['organization'].nunique()}")

# total unique organizations for vulnerabilities
print(f"Total unique organizations in vulnerabilities: {vulnerabilities['Organization'].nunique()}")


# lowercase organization names for merging
main['organization'] = main['organization'].str.lower()
profiles['organization'] = profiles['organization'].str.lower()
repositories['organization'] = repositories['organization'].str.lower()
libs_with_details['organization'] = libs_with_details['organization'].str.lower()
vulnerabilities['Organization'] = vulnerabilities['Organization'].str.lower()
# Out:
# Total unique organizations in main: 274
# Total unique organizations in profiles: 642
# Total unique organizations in repos: 504
# Total unique organizations in libraries: 522
# Total unique organizations in vulnerabilities: 461

# %% [markdown]
# # Filter all

# %%
# filter all files with organizations that exist in main
main_orgs = set(main['organization'].unique())
profiles = profiles[profiles['organization'].isin(main_orgs)]
repositories = repositories[repositories['organization'].isin(main_orgs)]
libs_with_details = libs_with_details[libs_with_details['organization'].isin(main_orgs)]
vulnerabilities = vulnerabilities[vulnerabilities['Organization'].isin(main_orgs)]
print(f"After filtering to only organizations in main:")
print(f"Total unique organizations in main: {main['organization'].nunique()}")
print(f"Total unique organizations in profiles: {profiles['organization'].nunique()}")
print(f"Total unique organizations in repos: {repositories['organization'].nunique()}")
print(f"Total unique organizations in libraries: {libs_with_details['organization'].nunique()}")
print(f"Total unique organizations in vulnerabilities: {vulnerabilities['Organization'].nunique()}")
# Out:
# After filtering to only organizations in main:
# Total unique organizations in main: 274
# Total unique organizations in profiles: 274
# Total unique organizations in repos: 243
# Total unique organizations in libraries: 220
# Total unique organizations in vulnerabilities: 200

# %%
# overwrite the csv files with the filtered data
profiles.to_csv('/Users/dmk6603/Documents/sbom_business_list/12_web_app/production_git/sbom_web_app/data/profiles_summary_complete.csv', index=False)
repositories.to_csv('/Users/dmk6603/Documents/sbom_business_list/12_web_app/production_git/sbom_web_app/data/repositories_summary_with_zero_libs.csv', index=False)
libs_with_details.to_csv('/Users/dmk6603/Documents/sbom_business_list/12_web_app/production_git/sbom_web_app/data/libraries_with_detailed_vulnerability_status.csv', index=False)
vulnerabilities.to_csv('/Users/dmk6603/Documents/sbom_business_list/12_web_app/production_git/sbom_web_app/data/vulnerability_summary.csv', index=False)

# %%
# /Users/dmk6603/Documents/sbom_business_list/12_web_app/production_git/sbom_web_app/data/affected_orgs/affected_orgs_affected_by_lib.csv
affected_orgs = pd.read_csv('/Users/dmk6603/Documents/sbom_business_list/12_web_app/production_git/sbom_web_app/data/affected_orgs/affected_orgs_affected_by_lib.csv')
# library,affected_organizations,affected_repositories,different_versions,different_paths,different_types,total_vulnerabilities
# actions/checkout,150,7456,84,2548,1,0
# ms,130,2276,13,846,1,24258


#/Users/dmk6603/Documents/sbom_business_list/12_web_app/production_git/sbom_web_app/data/affected_orgs/affected_orgs_affected_by_lib_version.csv
affected_orgs_by_version = pd.read_csv('/Users/dmk6603/Documents/sbom_business_list/12_web_app/production_git/sbom_web_app/data/affected_orgs/affected_orgs_affected_by_lib_version.csv')
# library,version,affected_organizations,affected_repositories,different_versions,different_paths,different_types,total_vulnerabilities
# actions/checkout,v4,125,2764,1,957,1,0
# actions/checkout,v2,124,2532,1,881,1,0
# Out:
# Total unique organizations in affected_orgs: 157
# Total unique organizations in affected_orgs_by_version: 153
